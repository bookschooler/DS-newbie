# %% [markdown]
# # Day1_0: 초고속 분석 환경 구축 (uv)
#
# ## 📚 학습 목표
#
# 1. **uv 명령어 익히기**: 터미널에서 uv 명령어 실행하기
# 2. **프로젝트 초기화**: `uv init`으로 새 프로젝트 만들기
# 3. **패키지 관리**: 패키지 추가하고 제거하기
# 4. **실행 환경**: `uv run`으로 스크립트 실행하기
#
# ---
#
# ## 🎯 왜 uv를 사용하나요?
#
# | 기능 | pip (기존) | uv (새로운 방식) |
# |------|------------|------------------|
# | 설치 속도 | 느림 | **10-100배 빠름!** |
# | 가상환경 | 수동으로 만들고 활성화 | **자동으로 관리** |
# | 실행 방법 | `source activate` 필요 | **`uv run` 한 번에!** |
#
# **분석가 관점**: pandas 같은 큰 라이브러리를 빠르게 설치하고, 프로젝트마다 깔끔하게 분리할 수 있습니다!
#
# ---
#
# ## 💻 uv 설치하기
#
# 터미널에서 다음 명령어를 실행하세요:
#
# ### MacOS / Linux
# ```bash
# curl -LsSf https://astral.sh/uv/install.sh | sh
# ```
#
# ### Windows (PowerShell)
# ```powershell
# powershell -c "irm https://astral.sh/uv/install.ps1 | iex"
# ```
#
# ---
#
# ## 📖 핵심 명령어
#
# ### 기본 명령어
#
# ```bash
# # 1. 버전 확인
# uv --version
#
# # 2. 새 프로젝트 만들기
# uv init
#
# # 3. 패키지 추가하기
# uv add pandas
# uv add numpy
#
# # 4. 패키지 목록 보기
# uv pip list
#
# # 5. 패키지 제거하기
# uv remove pandas
#
# # 6. 개발용 패키지 추가
# uv add --dev pytest
#
# # 7. Python 스크립트 실행
# uv run python my_script.py
# ```
#
# ### 생성되는 파일들
#
# - **`pyproject.toml`**: 프로젝트 설정 파일 (패키지 목록 저장)
# - **`.python-version`**: 사용할 Python 버전
# - **`uv.lock`**: 정확한 패키지 버전 기록
#
# ---

# %% [markdown]
# ## 🎯 실습 퀴즈
#
# **난이도**: ⭐ (쉬움) ~ ⭐⭐⭐ (보통)
#
# **참고**: 각 셀에서 `%%bash`를 사용하면 터미널 명령어를 실행할 수 있습니다!
#
# ---

# %% [markdown]
# ### Q1. uv 버전 확인하기 ⭐
#
# **문제**: uv가 올바르게 설치되었는지 확인하세요.
#
# **실행할 명령어**:
# ```bash
# uv --version
# ```
#
# **힌트**: 셀 맨 위에 `%%bash`를 쓰거나, 명령어 앞에 `!`를 붙이면 됩니다.

# %%
# 방법 1: ! 사용
# !uv --version

# %%
# %%bash
# # 방법 2: %%bash 사용
# uv --version

# %% [markdown]
# ### Q2. 프로젝트 초기화하기 ⭐
#
# **문제**: `my_first_project`라는 이름의 새 프로젝트를 만드세요.
#
# **단계**:
# 1. `/tmp` 폴더로 이동
# 2. `my_first_project` 디렉토리 생성
# 3. 해당 디렉토리에서 `uv init` 실행
# 4. 생성된 파일 확인
#
# **기대 결과**: `pyproject.toml`, `.python-version`, `README.md` 파일이 생성됩니다.

# %%
# %%bash
# # 여기에 명령어를 작성하세요
# cd /tmp
# mkdir -p my_first_project
# cd my_first_project
# uv init
#
# # 생성된 파일 확인
# echo "=== 생성된 파일 ==="
# ls -lh

# %% [markdown]
# ### Q3. 패키지 추가하기 ⭐⭐
#
# **문제**: 프로젝트에 `pandas` 패키지를 추가하세요.
#
# **명령어**: `uv add pandas`
#
# **추가 과제**: 패키지 추가 후 `pyproject.toml` 파일 내용을 확인하세요.

# %%
# %%bash
# # 여기에 명령어를 작성하세요
# cd /tmp/my_first_project
#
# # pandas 추가
# uv add pandas
#
# # pyproject.toml 확인
# echo "\n=== pyproject.toml 내용 ==="
# cat pyproject.toml

# %% [markdown]
# ### Q4. 설치된 패키지 목록 확인하기 ⭐⭐
#
# **문제**: 현재 프로젝트에 설치된 모든 패키지를 확인하세요.
#
# **명령어**: `uv pip list`
#
# **확인 사항**: pandas와 pandas가 의존하는 다른 패키지들(numpy 등)이 함께 설치되었는지 확인하세요.

# %%
# %%bash
# # 여기에 명령어를 작성하세요
# cd /tmp/my_first_project
#
# echo "=== 설치된 패키지 목록 ==="
# uv pip list

# %% [markdown]
# ### Q5. 패키지 제거하기 ⭐⭐
#
# **문제**: 설치했던 `pandas` 패키지를 제거하세요.
#
# **명령어**: `uv remove pandas`
#
# **확인**: 제거 후 다시 `uv pip list`를 실행하여 pandas가 제거되었는지 확인하세요.

# %%
# %%bash
# # 여기에 명령어를 작성하세요
# cd /tmp/my_first_project
#
# # pandas 제거
# uv remove pandas
#
# echo "\n=== 제거 후 패키지 목록 ==="
# uv pip list

# %% [markdown]
# ### Q6. 개발 의존성 추가하기 ⭐⭐⭐ (이 부분은 생략하고 넘어가겠습니다)
#
# **문제**: 테스트용 패키지 `pytest`를 **개발 의존성**으로 추가하세요.
#
# **개발 의존성이란?**
# - 실제 프로그램 실행에는 필요 없지만
# - 개발/테스트할 때만 필요한 패키지
# - 예: pytest (테스트), black (코드 포맷팅)
#
# **명령어**: `uv add --dev pytest`
#
# **확인**: `pyproject.toml`에서 `[project.optional-dependencies]` 섹션에 pytest가 추가되었는지 확인하세요.

# %%
# %%bash
# # 여기에 명령어를 작성하세요
# cd /tmp/my_first_project
#
# # pytest를 개발 의존성으로 추가
# uv add --dev pytest
#
# echo "\n=== pyproject.toml 확인 ==="
# cat pyproject.toml

# %% [markdown]
# ### Q7. 간단한 스크립트 실행하기 ⭐⭐⭐
#
# **문제**: 간단한 Python 스크립트를 만들고 `uv run`으로 실행하세요.
#
# **단계**:
# 1. `hello.py` 파일 생성 (아래 코드 사용)
# 2. `uv run python hello.py`로 실행

# %%
# %%writefile /tmp/test_project/hello.py
print("=== uv 환경 구축 성공! ===")
print("Hello from my first uv project!")
print("이제 데이터 분석을 시작할 준비가 되었습니다!")
# Out:
# Writing /tmp/test_project/hello.py

# %%
# 스크립트 실행
# !cd /tmp/test_project && uv run python hello.py
# Out:
# === uv 환경 구축 성공! ===
# Hello from my first uv project!
# 이제 데이터 분석을 시작할 준비가 되었습니다!

# %% [markdown]
# ---
#
# ## 📊 학습 정리
#
# ### 핵심 명령어 요약
#
# | 명령어 | 기능 | 사용 예시 |
# |--------|------|----------|
# | `uv --version` | 버전 확인 | `uv --version` |
# | `uv init` | 프로젝트 초기화 | `uv init` |
# | `uv add` | 패키지 추가 | `uv add pandas` |
# | `uv add --dev` | 개발 패키지 추가 | `uv add --dev pytest` |
# | `uv remove` | 패키지 제거 | `uv remove pandas` |
# | `uv pip list` | 패키지 목록 | `uv pip list` |
# | `uv run` | 스크립트 실행 | `uv run python script.py` |
#
# ### pip vs uv 비교
#
# | 작업 | pip (기존 방식) | uv (새로운 방식) |
# |------|----------------|------------------|
# | 가상환경 생성 | `python -m venv .venv` | 자동 생성 |
# | 환경 활성화 | `source .venv/bin/activate` | **불필요!** |
# | 패키지 설치 | `pip install pandas` | `uv add pandas` |
# | 스크립트 실행 | `python script.py` | `uv run python script.py` |
#
# ### 💡 실무 활용 팁
#
# 1. **새 프로젝트 시작**: 항상 `uv init`으로 시작하기
# 2. **패키지 관리**: `uv add`로 추가, 자동으로 `pyproject.toml`에 기록됨
# 3. **개발 도구**: 테스트/린팅 도구는 `--dev` 플래그로 추가
# 4. **팀 협업**: `pyproject.toml`과 `uv.lock`을 Git에 올리기
# 5. **빠른 실행**: `uv run`으로 activate 없이 바로 실행
#
# ### 🎯 다음 단계는?
#
# uv로 환경 구축을 완료했습니다! 이제 본격적인 Python 프로그래밍을 시작합니다.
#
# **다음 노트북**: `Day1_1_데이터_구조_심화_Collection.ipynb`
# - 리스트 컴프리헨션으로 데이터 필터링
# - 딕셔너리로 VLOOKUP 구현
# - 튜플 언패킹으로 우아한 코드 작성
